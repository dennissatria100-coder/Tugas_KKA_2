# %% [markdown]
# <a href="https://colab.research.google.com/github/dennissatria100-coder/Tugas_KKA_2/blob/main/PraktikumOOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Hero:
 # Constructor: Dijalankan saat Hero baru dibuat
  def __init__(self, name, hp, attack_power):
    self.name = name # Nama Hero
    self.hp = hp # Nyawa (Health Point)
    self.attack_power = attack_power # Kekuatan Serangan
 # Method untuk menampilkan info hero
  def info(self):
     print(f"Hero:{self.name} | HP: {self.hp} | Power: {self.attack_power}")

  # Method menyerang: Objek ini (self) menyerang objek lain (lawan)
  def serang(self, lawan):
    print(f"{self.name} menyerang {lawan.name}!")
    lawan.diserang(self.attack_power)

  # Method diserang: Menerima damage
  def diserang(self, damage):
    self.hp -= damage
    print(f"{self.name} terkena damage {damage}. Sisa HP:{self.hp}")
# Tambah kode Output di akhir program


# -- Main Program --
# Membuat Object (Instansiasi)
hero1 = Hero("Layla", 100, 15)
hero2 = Hero("Zilong", 120, 20)
hero1.hp = 500

# Memanggil Method
hero1.info()
hero2.info()

print("\n--- Pertarungan Dimulai ---")
hero1.serang(hero2) # Layla menyerang Zilong
hero2.serang(hero1) # Zilong membalas
# Out:
# Hero:Layla | HP: 500 | Power: 15
# Hero:Zilong | HP: 120 | Power: 20
#
# --- Pertarungan Dimulai ---
# Layla menyerang Zilong!
# Zilong terkena damage 15. Sisa HP:105
# Zilong menyerang Layla!
# Layla terkena damage 20. Sisa HP:480

# %% [markdown]
# Analisis 1
#
#
# > 0 berubah menjadi 500 karena atribut hp dapat diubah secara langsung.**Tugas Analisis 1**
#
# Nilai HP pada object hero1 yang awalnya 10

# %% [markdown]
# Tugas Analisis 2
#
# Karena parameter lawan membutuhkan object agar dapat mengakses atribut dan method dari hero yang diserang.

# %%
class Hero:
 # Constructor: Dijalankan saat Hero baru dibuat
  def __init__(self, name, hp, attack_power):
    self.name = name # Nama Hero
    self.hp = hp # Nyawa (Health Point)
    self.attack_power = attack_power # Kekuatan Serangan
 # Method untuk menampilkan info hero
  def info(self):
     print(f"Hero:{self.name} | HP: {self.hp} | Power: {self.attack_power}")

  # Method menyerang: Objek ini (self) menyerang objek lain (lawan)
  def serang(self, lawan):
    print(f"{self.name} menyerang {lawan.name}!")
    lawan.diserang(self.attack_power)

  # Method diserang: Menerima damage
  def diserang(self, damage):
    self.hp -= damage
    print(f"{self.name} terkena damage {damage}. Sisa HP:{self.hp}")
# Tambah kode Output di akhir program


# -- Main Program --
# Membuat Object (Instansiasi)
hero1 = Hero("Layla", 100, 15)
hero2 = Hero("Zilong", 120, 20)
hero1.hp = 500

# Memanggil Method
hero1.info()
hero2.info()

print("\n--- Pertarungan Dimulai ---")
hero1.serang(hero2) # Layla menyerang Zilong
hero2.serang(hero1) # Zilong membalas
# Out:
# Hero:Layla | HP: 500 | Power: 15
# Hero:Zilong | HP: 120 | Power: 20
#
# --- Pertarungan Dimulai ---
# Layla menyerang Zilong!
# Zilong terkena damage 15. Sisa HP:105
# Zilong menyerang Layla!
# Layla terkena damage 20. Sisa HP:480

# %% [markdown]
# Tugas Analisis 3
#
# Jika super().init() dihapus, akan terjadi error karena atribut name dan hp dari class Hero tidak dibuat di object Mage.
#
# Fungsi super() berperan memanggil constructor class induk agar data dari class Mage dapat diteruskan dan digunakan di class Hero.

# %%
class Hero:
  def __init__(self, nama, hp_awal):
    self.nama = nama
    # Enkapsulasi: HP bersifat Private (hanya bisa diakses di dalam class ini)
    self.__hp = hp_awal

  # GETTER: Cara resmi melihat HP
  def get_hp(self):
    return self.__hp

  # SETTER: Cara resmi mengubah HP (dengan validasi)
  def set_hp(self, nilai_baru):
    if nilai_baru < 0:
      self.__hp = 0 # HP tidak boleh negatif
    elif nilai_baru > 1000:
      print("Cheat terdeteksi! HP dimaksimalkan ke 1000 saja.")
      self.__hp = 1000
    else:
      self.__hp = nilai_baru
  def diserang(self, damage):
    # Kita pakai setter/getter bahkan di dalam class sendiri agar aman
    sisa_hp = self.get_hp() - damage
    self.set_hp(sisa_hp)
    print(f"{self.nama} terkena damage {damage}. Sisa HP: {self.get_hp()}")

# -- Uji Coba --
hero1 = Hero("Layla", 100)

# hero1.__hp = 9999 # GAGAL (Tidak akan mengubah hp asli)
# print(hero1.__hp) # ERROR (Tidak bisa dibaca langsung)

hero1.set_hp(-50) # Coba set negatif
print(hero1.get_hp()) # Output: 0 (Karena dicegat oleh logika Setter)
# Out:
# 0

# %% [markdown]
# Tugas Analisis 4
#
# 1.Percobaan Hacking
#
# HP akan muncul, bukan Error. ini terjadi karena Python menggunakan konsep Name Mangling. Atribut __hp secara internal diubah menjadi _Hero__hp, sehingga masih dapat diakses menggunakan nama tersebut. Namun, cara ini tidak disarankan dalam pemrograman yang baik karena melewati konsep enkapsulasi dan aturan akses yang sudah dibuat oleh class. Seharusnya HP diakses melalui method get_hp() dan diubah melalui set_hp() agar validasi tetap berjalan.
#
# 2.Uji Validasi
#
# HP Hero akan menjadi -100 karena tidak ada lagi pengecekan nilai.
#
# Setter sangat penting untuk menjaga integritas data dalam game karena setter dapat memberikan validasi sebelum data diubah. Dengan adanya setter, HP dapat dibatasi, misalnya tidak boleh kurang dari 0 dan tidak boleh lebih dari 1000, sehingga data tetap sesuai dengan aturan game dan tidak dapat diubah menjadi nilai yang tidak valid.

# %%
from abc import ABC, abstractmethod

# 1. Interface / Abstract Class
# Ini adalah KONTRAK. Semua turunan wajib punya method di bawah ini.

class GameUnit(ABC):

    @abstractmethod
    def serang(self, target):
        pass

    @abstractmethod
    def info(self):
        pass

# 2. Implementasi pada Class Konkret
class Hero(GameUnit):
      def __init__(self, nama):
          self.nama = nama

      # Kita WAJIB membuat method serang, kalau tidak akan Error
      def serang(self, target):
        print(f"Hero {self.nama} menebas {target}!")

      def info(self):
        print(f"Saya adalah Hero: {self.nama}")

class Monster(GameUnit):
    def __init__(self, jenis):
        self.jenis = jenis

    # Implementasi serang versi Monster
    def serang(self, target):
        print(f"Monster {self.jenis} menggigit {target}!")

    def info(self):
        print(f"Saya adalah Monster: {self.jenis}")

# -- Uji Coba --
# unit = GameUnit() # ERROR! Abstract class tidak bisa jadi objek.
h = Hero("Alucard")
m = Monster("Serigala")
h.info()
m.info()


# ANALISIS 1: MELANGGAR KONTRAK
# ==================================================

class HeroAnalisis(GameUnit):
    def __init__(self, nama):
        self.nama = nama

    def info(self):
        print(f"Saya adalah Hero: {self.nama}")


try:
    h_analisis = HeroAnalisis("Alucard")
except TypeError as error:
    print("\nAnalisis 1:")
    print(error)


# ==================================================
# ANALISIS 2: MEMBUAT OBJECT ABSTRACT CLASS
# ==================================================

try:
    unit = GameUnit()
except TypeError as error:
    print("\nAnalisis 2:")
    print(error)
# Out:
# Saya adalah Hero: Alucard
# Saya adalah Monster: Serigala
#
# Analisis 1:
# Can't instantiate abstract class HeroAnalisis without an implementation for abstract method 'serang'
#
# Analisis 2:
# Can't instantiate abstract class GameUnit without an implementation for abstract methods 'info', 'serang'

# %% [markdown]
# Analisis 5
#
# 1. Melanggar Kontrak: muncul error Can't instantiate abstract class HeroAnalisis with abstract method serang. Artinya, HeroAnalisis tidak bisa dibuat menjadi objek karena belum memenuhi method wajib serang().
#
# 2. Mencetak Cetakan: muncul error karena GameUnit adalah abstract class, sehingga tidak boleh dibuat menjadi objek langsung. GameUnit digunakan sebagai aturan dasar/kontrak untuk class turunannya.

# %%
# Parent Class
class Hero:
    def __init__(self, nama):
        self.nama = nama

    def serang(self):
        print("Hero menyerang dengan tangan kosong.")

# Child Class 1
class Mage(Hero):
    def serang(self):
        print(f"{self.nama} (Mage) menembakkan Bola Api! Boom!")

# Child Class 2
class Archer(Hero):
    def serang(self):
        print(f"{self.nama} (Archer) memanah dari jauh! Jleb!")

# Child Class 3
class Fighter(Hero):
    def serang(self):
        print(f"{self.nama} (Fighter) memukul dengan pedang! Slash!")

# -- Penerapan Polymorphism --
# Kita punya daftar hero campuran
pasukan = [
 Mage("Eudora"),
 Archer("Miya"),
 Fighter("Zilong"),
 Mage("Gord")
]

print("--- PERANG DIMULAI ---")
# Satu perintah loop, tapi respon berbeda-beda (Polymorphism)
for pahlawan in pasukan:
 pahlawan.serang()

# %% [markdown]
# Tugas Analisis 6:
#
# Uji Skalabilitas (Kemudahan Menambah Fitur): Tanpa mengubah satu huruf pun pada kode Looping (for pahlawan in pasukan:), buatlah satu class baru bernama Healer(Hero). Isi method serang milik Healer dengan: print(f"{self.name} tidak menyerang, tapi menyembuhkan teman!"). Masukkan objek Healer ke dalam list pasukan. o Pertanyaan: Apakah program berjalan lancar? o Kesimpulannya, apa keuntungan Polimorfisme bagi seorang programmer ketika harus mengupdate game dengan karakter baru di masa depan?
# Konsistensi Penamaan: Ubah nama method serang pada class Archer menjadi tembak_panah. Jalankan program. Pertanyaan: Apa yang terjadi? Mengapa dalam konsep Polimorfisme, nama method antara Parent Class dan berbagai Child Class harus persis sama?

# %% [markdown]
# D. PROJECT CHARTER
#
# **Nama Anggota Kelompok:**
# 1. Dennis satria putra basuki
# 2. Deniza nabiel akbar alfatih
#
# **Dataset yang Dipilih:**
# Data Penjualan Kantin/Toko
#
# **Pertanyaan Analisis Awal:**
# 1. Menu apa yang paling banyak terjual?
# 2. Menu apa yang menghasilkan pendapatan terbesar?
# 3. Berapa total pendapatan dari setiap menu?
#
# **Dugaan Masalah Kualitas Data:**
# - Missing value pada kolom: terjual
# - Duplikat data
# - Tipe data tidak sesuai pada kolom: harga
# - Data kosong pada beberapa kolom
#
# **Rencana Teknik Pembersihan:**
# Mengisi missing value pada kolom terjual dengan 0,
# menghapus data dengan menu kosong, menghapus data duplikat,
# dan mengubah tipe data harga menjadi integer.
#
# **Rencana Manipulasi Data:**
# Filter: terjual > 20
# Sort: terjual dari terbesar ke terkecil
# Kolom turunan: total_pendapatan = harga * terjual
# Groupby/agregasi: total pendapatan berdasarkan menu
#
# **Jadwal Kerja:**
# P3 (Loading & Inspection): Membaca dan mengecek dataset
# P4 (Cleaning): Membersihkan missing value dan duplikat
# P5 (Manipulation): Filter, sorting, kolom turunan, dan groupby
# P6 (Uji & Presentasi): Mengecek hasil dan membuat presentasi
#
# Pembagian Peran: **teks tebal**
# Anggota 1: Cleaning Data
# Anggota 2: Analisis & Presentasi Data
